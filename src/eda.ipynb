# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
train = pd.read_csv("../data/train.csv")
train.head()
# Out:
# /anaconda2/envs/env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
# ...

# %%
test = pd.read_csv("../data/test.csv")
test.head()
# Out:
# /anaconda2/envs/env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   channelGrouping      date  \
# 0  Organic Search  20171016
# 1  Organic Search  20171016
# 2  Organic Search  20171016
# 3  Organic Search  20171016
# 4  Organic Search  20171016
#
# ...

# %%
sample = pd.read_csv("../data/sample_submission.csv")
sample.head()
# Out:
#          fullVisitorId  PredictedLogRevenue
# 0  0000000259678714014                  0.0
# 1  0000049363351866189                  0.0
# 2  0000053049821714864                  0.0
# 3  0000059488412965267                  0.0
# 4  0000085840370633780                  0.0

# %%
train.columns
# Out:
# Index(['channelGrouping', 'date', 'device', 'fullVisitorId', 'geoNetwork',
#        'sessionId', 'socialEngagementType', 'totals', 'trafficSource',
#        'visitId', 'visitNumber', 'visitStartTime'],
#       dtype='object')

# %%
train.channelGrouping.unique()
# Out:
# array(['Organic Search', 'Referral', 'Paid Search', 'Affiliates',
#        'Direct', 'Display', 'Social', '(Other)'], dtype=object)

# %%
train.device
# Out:
# 0         {"browser": "Chrome", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Windows", "operatingSystemVersion": "not available in demo dataset", "isMobile": false, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "desktop"}
# ...

# %%
test.device
# Out:
# 0         {"browser": "Chrome", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Macintosh", "operatingSystemVersion": "not available in demo dataset", "isMobile": false, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "desktop"}
# ...

# %%
print(len(train.fullVisitorId.unique()))
print(len(train.fullVisitorId))
# Out:
# 742735
# 903653

# %%
print(len(test.fullVisitorId.unique()))
print(len(test.fullVisitorId))
# Out:
# 652237
# 804684

# %%
train.geoNetwork
# Out:
# 0         {"continent": "Asia", "subContinent": "Western Asia", "country": "Turkey", "region": "Izmir", "metro": "(not set)", "city": "Izmir", "cityId": "not available in demo dataset", "networkDomain": "ttnet.com.tr", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}
# 1         {"continent": "Oceania", "subContinent": "Australasia", "country": "Australia", "region": "not available in demo dataset", "metro": "not available in demo dataset", "city": "not available in demo dataset", "cityId": "not available in demo dataset", "networkDomain": "dodo.net.au", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}
# ...

# %%
print(train.sessionId.nunique())
print(len(train.sessionId))
# Out:
# 902755
# 903653

# %%
print(test.sessionId.nunique())
print(len(test.sessionId))
# Out:
# 803863
# 804684

# %%
test.socialEngagementType.unique()
# Out:
# array(['Not Socially Engaged'], dtype=object)

# %%
train[train.sessionId.duplicated()]
# Out:
#        channelGrouping      date  \
# 50181   Organic Search  20170624
# 78892   Paid Search     20170616
# 80071   Paid Search     20170616
# 89617   Paid Search     20161130
# 89962   Organic Search  20161130
# 91550   Social          20161130
# 92145   Social          20161130
# 118127  Organic Search  20170421
# 119422  Organic Search  20170421
# 135770  Direct          20170115
# 135809  Organic Search  20170115
# 136021  Paid Search     20170115
# 146875  Organic Search  20170311
# 147019  Direct          20170311
# 147059  Affiliates      20170311
# 147457  Organic Search  20170311
# 147488  Affiliates      20170311
# 147684  Organic Search  20170311
# 147826  Referral        20170311
# 149158  Referral        20170622
# 149769  Affiliates      20170622
# 150042  Affiliates      20170622
# 150382  Direct          20170622
# 150440  Referral        20170622
# 150490  Direct          20170622
# 150550  Organic Search  20170622
# 150598  Organic Search  20170622
# ...

# %%
train[train.sessionId=="946085548949296102_1480492063"]
# Out:
#       channelGrouping      date  \
# 83399  Paid Search     20161129
# 89617  Paid Search     20161130
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 device  \
# ...

# %%
train.dtypes
# Out:
# channelGrouping         object
# date                    int64
# device                  object
# fullVisitorId           object
# geoNetwork              object
# sessionId               object
# socialEngagementType    object
# totals                  object
# trafficSource           object
# visitId                 int64
# visitNumber             int64
# visitStartTime          int64
# dtype: object

# %%
def get_totals(s):
    d = json.loads(s)
    if "transactionRevenue" in d:
        return d["transactionRevenue"]
    else:
        return 0

import json
prices = train.totals.apply(get_totals)

# %%
prices[prices!=0]
# Out:
# 752       37860000
# 753       306670000
# 799       68030000
# 802       26250000
# 859       574150000
# 866       8380000
# 893       395730000
# 910       24080000
# 922       35480000
# 925       35080000
# 930       81500000
# 942       546320000
# 971       63840000
# 974       117340000
# 976       43710000
# 999       34480000
# 1000      35390000
# 1008      339030000
# 1020      33670000
# 1022      635500000
# 1026      103240000
# 1027      305470000
# 1037      5150000
# 1041      90850000
# 1054      10590000
# 1055      25680000
# 1056      338970000
# 2774      593910000
# 3161      44790000
# 3268      30390000
#             ...
# 899951    43430000
# 903089    44790000
# 903118    175800000
# 903122    87990000
# 903167    14370000
# 903168    155970000
# 903189    75180000
# 903194    350000000
# 903201    135920000
# 903211    159980000
# 903222    23180000
# 903228    22970000
# 903234    463600000
# 903235    79990000
# 903243    76780000
# 903249    12990000
# ...

# %%
from pandas.io.json import json_normalize
json_normalize(train.geoNetwork.apply(json.loads))
# Out:
#                                  city                         cityId  \
# 0       Izmir                          not available in demo dataset
# 1       not available in demo dataset  not available in demo dataset
# 2       Madrid                         not available in demo dataset
# 3       not available in demo dataset  not available in demo dataset
# 4       not available in demo dataset  not available in demo dataset
# 5       not available in demo dataset  not available in demo dataset
# 6       not available in demo dataset  not available in demo dataset
# 7       Brisbane                       not available in demo dataset
# 8       not available in demo dataset  not available in demo dataset
# 9       not available in demo dataset  not available in demo dataset
# 10      not available in demo dataset  not available in demo dataset
# 11      not available in demo dataset  not available in demo dataset
# 12      Izmir                          not available in demo dataset
# ...
